# %%
import matplotlib.pyplot as plt
import torch
import imageio

# %%
def draw_plots(
    results: list, 
    timesteps: int = int(1e6), 
    val_freq: int = int(1e5)
):
    torch_objs = []
    for result in results:
        torch_objs.append(torch.load(result, weights_only=False))
    
    fig, ax = plt.subplots(2, 2, figsize=(16, 8))
